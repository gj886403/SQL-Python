# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# The engine creates a Dialect object tailored towards PostgreSQL, as well as a Pool object which
#  will establish a DBAPI connection at localhost:5432 when a connection request is first
#  received. Note that the Engine and its underlying Pool do not establish the first actual
#  DBAPI connection until the Engine.connect() method is called, or an operation which is
#  dependent on this method such as Engine.execute() is invoked.
#  In this way, Engine and Pool can be said to have a lazy initialization behavior

# %%
# Creating the engine
engine = create_engine('postgresql://postgres:l=den1TiFT@localhost:5432/dvdrental')

# %%
query1 = "SELECT * FROM actor;"  # String containing the SQL query to select all rows
# Import the data into DataFrame df
df_actor = pd.read_sql_query(query1, engine, parse_dates=['last_update'], index_col='last_update')  

query2 = "SELECT * FROM address;" 
df_address = pd.read_sql_query(query2, engine, parse_dates=['last_update'], index_col='last_update')  

query3 = "SELECT * FROM category;" 
df_category = pd.read_sql_query(query3, engine, parse_dates=['last_update'], index_col='last_update')

query4 = "SELECT * FROM city;"
df_city = pd.read_sql_query(query4, engine, parse_dates=['last_update'], index_col='last_update') 

query5 = "SELECT * FROM country;"  
df_country = pd.read_sql_query(query5, engine, parse_dates=['last_update'], index_col='last_update') 

query6 = "SELECT * FROM customer;"  
df_customer = pd.read_sql_query(query6, engine, parse_dates=['last_update'], index_col='last_update') 

query7 = "SELECT * FROM film;"  
df_film = pd.read_sql_query(query7, engine, parse_dates=['last_update'], index_col='last_update') 

query8 = "SELECT * FROM film_actor;"  
df_film_actor = pd.read_sql_query(query8, engine, parse_dates=['last_update'], index_col='last_update') 

query9 = "SELECT * FROM film_category;"  
df_film_category = pd.read_sql_query(query9, engine, parse_dates=['last_update'], index_col='last_update') 

query10 = "SELECT * FROM inventory;"  
df_inventory = pd.read_sql_query(query10, engine, parse_dates=['last_update'], index_col='last_update')  

query11 = "SELECT * FROM language;" 
df_actor = pd.read_sql_query(query11, engine, parse_dates=['last_update'], index_col='last_update') 

# Parse payment_date column as dates
query12 = "SELECT * FROM payment;"  
df_language = pd.read_sql_query(query12, engine, parse_dates=['payment_date'], index_col='payment_date') 
# Parse rental_date, return_date & last_update columns as dates
query13 = "SELECT * FROM rental;"  
df_rental = pd.read_sql_query(query13, engine, parse_dates=['rental_date','return_date','last_update'])

query14 = "SELECT * FROM staff;"  
df_staff = pd.read_sql_query(query14, engine, parse_dates=['last_update'], index_col='last_update') 

query15 = "SELECT * FROM store;"  
df_store = pd.read_sql_query(query15, engine, parse_dates=['last_update'], index_col='last_update')

# %%
df_customer.head()
# Out:
#                          customer_id  store_id first_name last_name  \
# last_update
# 2013-05-26 14:49:45.738          524         1      Jared       Ely
# 2013-05-26 14:49:45.738            1         1       Mary     Smith
# 2013-05-26 14:49:45.738            2         1   Patricia   Johnson
# 2013-05-26 14:49:45.738            3         1      Linda  Williams
# 2013-05-26 14:49:45.738            4         2    Barbara     Jones
#
#                                                        email  address_id  \
# last_update
# 2013-05-26 14:49:45.738         jared.ely@sakilacustomer.org         530
# 2013-05-26 14:49:45.738        mary.smith@sakilacustomer.org           5
# 2013-05-26 14:49:45.738  patricia.johnson@sakilacustomer.org           6
# 2013-05-26 14:49:45.738    linda.williams@sakilacustomer.org           7
# 2013-05-26 14:49:45.738     barbara.jones@sakilacustomer.org           8
#
#                          activebool create_date  active
# last_update
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1

# %%
m_names = df_customer[df_customer['first_name'].str.contains("M")]
m_names
# Out:
#                          customer_id  store_id first_name     last_name  \
# last_update
# 2013-05-26 14:49:45.738            1         1       Mary         Smith
# 2013-05-26 14:49:45.738            7         1      Maria        Miller
# 2013-05-26 14:49:45.738            9         2   Margaret         Moore
# 2013-05-26 14:49:45.738           21         1   Michelle         Clark
# 2013-05-26 14:49:45.738           30         1    Melissa          King
# 2013-05-26 14:49:45.738           38         1     Martha      Gonzalez
# 2013-05-26 14:49:45.738           44         1      Marie        Turner
# 2013-05-26 14:49:45.738           60         1    Mildred        Bailey
# 2013-05-26 14:49:45.738           80         1    Marilyn          Ross
# 2013-05-26 14:49:45.738          128         1   Marjorie        Tucker
# 2013-05-26 14:49:45.738          131         2     Monica         Hicks
# 2013-05-26 14:49:45.738          151         2      Megan        Palmer
# 2013-05-26 14:49:45.738          154         2    Michele         Grant
# 2013-05-26 14:49:45.738          178         2     Marion        Snyder
# 2013-05-26 14:49:45.738          188         1    Melanie     Armstrong
# 2013-05-26 14:49:45.738          223         1    Melinda     Fernandez
# 2013-05-26 14:49:45.738          226         2    Maureen        Little
# 2013-05-26 14:49:45.738          236         1     Marcia          Dean
# 2013-05-26 14:49:45.738          239         2     Minnie        Romero
# 2013-05-26 14:49:45.738          240         1    Marlene         Welch
# 2013-05-26 14:49:45.738          246         1     Marian       Mendoza
# 2013-05-26 14:49:45.738          252         2     Mattie       Hoffman
# 2013-05-26 14:49:45.738          254         2     Maxine         Silva
# 2013-05-26 14:49:45.738          256         2      Mabel       Holland
# 2013-05-26 14:49:45.738          257         2     Marsha       Douglas
# 2013-05-26 14:49:45.738          258         1     Myrtle       Fleming
# 2013-05-26 14:49:45.738          267         1     Margie          Wade
# 2013-05-26 14:49:45.738          285         1     Miriam      Mckinney
# 2013-05-26 14:49:45.738          292         2      Misty       Lambert
# 2013-05-26 14:49:45.738          293         2        Mae      Fletcher
# 2013-05-26 14:49:45.738          302         1    Michael     Silverman
# 2013-05-26 14:49:45.738          312         2       Mark      Rinehart
# 2013-05-26 14:49:45.738          323         2    Matthew         Mahan
# 2013-05-26 14:49:45.738          383         1     Martin         Bales
# 2013-05-26 14:49:45.738          403         1       Mike           Way
# 2013-05-26 14:49:45.738          408         1     Manuel       Murrell
# 2013-05-26 14:49:45.738          413         2     Marvin           Yee
# 2013-05-26 14:49:45.738          422         1     Melvin     Ellington
# 2013-05-26 14:49:45.738          441         1      Mario      Cheatham
# 2013-05-26 14:49:45.738          444         2     Marcus       Hidalgo
# 2013-05-26 14:49:45.738          445         1    Micheal        Forman
# 2013-05-26 14:49:45.738          448         1     Miguel    Betancourt
# 2013-05-26 14:49:45.738          482         1    Maurice       Crawley
# 2013-05-26 14:49:45.738          499         2       Marc        Outlaw
# 2013-05-26 14:49:45.738          508         2     Milton       Howland
# 2013-05-26 14:49:45.738          520         2   Mitchell  Westmoreland
# 2013-05-26 14:49:45.738          539         1     Mathew         Bolin
# 2013-05-26 14:49:45.738          553         1        Max          Pitt
# 2013-05-26 14:49:45.738          576         2     Morris      Mccarter
# 2013-05-26 14:49:45.738          583         1   Marshall         Thorn
# 2013-05-26 14:49:45.738          588         1     Marion        Ocampo
#
#                                                             email  address_id  \
# last_update
# 2013-05-26 14:49:45.738             mary.smith@sakilacustomer.org           5
# 2013-05-26 14:49:45.738           maria.miller@sakilacustomer.org          11
# 2013-05-26 14:49:45.738         margaret.moore@sakilacustomer.org          13
# 2013-05-26 14:49:45.738         michelle.clark@sakilacustomer.org          25
# 2013-05-26 14:49:45.738           melissa.king@sakilacustomer.org          34
# 2013-05-26 14:49:45.738        martha.gonzalez@sakilacustomer.org          42
# 2013-05-26 14:49:45.738           marie.turner@sakilacustomer.org          48
# 2013-05-26 14:49:45.738         mildred.bailey@sakilacustomer.org          64
# 2013-05-26 14:49:45.738           marilyn.ross@sakilacustomer.org          84
# 2013-05-26 14:49:45.738        marjorie.tucker@sakilacustomer.org         132
# 2013-05-26 14:49:45.738           monica.hicks@sakilacustomer.org         135
# 2013-05-26 14:49:45.738           megan.palmer@sakilacustomer.org         155
# 2013-05-26 14:49:45.738          michele.grant@sakilacustomer.org         158
# 2013-05-26 14:49:45.738          marion.snyder@sakilacustomer.org         182
# 2013-05-26 14:49:45.738      melanie.armstrong@sakilacustomer.org         192
# 2013-05-26 14:49:45.738      melinda.fernandez@sakilacustomer.org         227
# 2013-05-26 14:49:45.738         maureen.little@sakilacustomer.org         230
# 2013-05-26 14:49:45.738            marcia.dean@sakilacustomer.org         240
# 2013-05-26 14:49:45.738          minnie.romero@sakilacustomer.org         243
# 2013-05-26 14:49:45.738          marlene.welch@sakilacustomer.org         244
# 2013-05-26 14:49:45.738         marian.mendoza@sakilacustomer.org         250
# 2013-05-26 14:49:45.738         mattie.hoffman@sakilacustomer.org         256
# 2013-05-26 14:49:45.738           maxine.silva@sakilacustomer.org         259
# 2013-05-26 14:49:45.738          mabel.holland@sakilacustomer.org         261
# 2013-05-26 14:49:45.738         marsha.douglas@sakilacustomer.org         262
# 2013-05-26 14:49:45.738         myrtle.fleming@sakilacustomer.org         263
# 2013-05-26 14:49:45.738            margie.wade@sakilacustomer.org         272
# 2013-05-26 14:49:45.738        miriam.mckinney@sakilacustomer.org         290
# 2013-05-26 14:49:45.738          misty.lambert@sakilacustomer.org         297
# 2013-05-26 14:49:45.738           mae.fletcher@sakilacustomer.org         298
# 2013-05-26 14:49:45.738      michael.silverman@sakilacustomer.org         307
# 2013-05-26 14:49:45.738          mark.rinehart@sakilacustomer.org         317
# 2013-05-26 14:49:45.738          matthew.mahan@sakilacustomer.org         328
# 2013-05-26 14:49:45.738           martin.bales@sakilacustomer.org         388
# 2013-05-26 14:49:45.738               mike.way@sakilacustomer.org         408
# 2013-05-26 14:49:45.738         manuel.murrell@sakilacustomer.org         413
# 2013-05-26 14:49:45.738             marvin.yee@sakilacustomer.org         418
# 2013-05-26 14:49:45.738       melvin.ellington@sakilacustomer.org         427
# 2013-05-26 14:49:45.738         mario.cheatham@sakilacustomer.org         446
# 2013-05-26 14:49:45.738         marcus.hidalgo@sakilacustomer.org         449
# 2013-05-26 14:49:45.738         micheal.forman@sakilacustomer.org         450
# 2013-05-26 14:49:45.738      miguel.betancourt@sakilacustomer.org         453
# 2013-05-26 14:49:45.738        maurice.crawley@sakilacustomer.org         487
# 2013-05-26 14:49:45.738            marc.outlaw@sakilacustomer.org         504
# 2013-05-26 14:49:45.738         milton.howland@sakilacustomer.org         513
# 2013-05-26 14:49:45.738  mitchell.westmoreland@sakilacustomer.org         526
# 2013-05-26 14:49:45.738           mathew.bolin@sakilacustomer.org         545
# 2013-05-26 14:49:45.738               max.pitt@sakilacustomer.org         559
# 2013-05-26 14:49:45.738        morris.mccarter@sakilacustomer.org         582
# 2013-05-26 14:49:45.738         marshall.thorn@sakilacustomer.org         589
# 2013-05-26 14:49:45.738          marion.ocampo@sakilacustomer.org         594
#
#                          activebool create_date  active
# last_update
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       0
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
# 2013-05-26 14:49:45.738        True  2006-02-14       1
